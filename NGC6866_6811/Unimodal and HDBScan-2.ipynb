# %%
import astropy.table as at
from astropy.table import QTable, Table, vstack, join
import numpy as np

# %%
# Load the unimodal results
unimodal = Table.read('unimodalcheck_200M_phase.csv', format='csv')

# Load the two cluster catalogs
cat_6811 = QTable.read('rcat_ngc6811_v0.fits')
cat_6866 = QTable.read('rcat_ngc6866_v0.fits')

# Add a cluster label so you know which cluster each star came from
cat_6811['cluster'] = 'NGC6811'
cat_6866['cluster'] = 'NGC6866'

# Stack them and keep only unique stars (some may appear in both)
catalog = vstack([cat_6811, cat_6866])
catalog = at.unique(catalog, keys='GAIAEDR3_ID')

# Rename the id column in unimodal table to match the catalog key
unimodal.rename_column('id', 'GAIAEDR3_ID')

# Join on GAIAEDR3_ID to only keeps stars present in both tables
matched = join(unimodal, catalog, keys='GAIAEDR3_ID', join_type='left')

# Summary
print(f"Stars in unimodal table:   {len(unimodal)}")
print(f"Stars matched to catalog:  {len(matched)}")
print(f"Unimodal stars:            {np.sum(matched['unimodal'] == 1)}")
print(f"Non-unimodal stars:        {np.sum(matched['unimodal'] == 0)}")

# Save the result
matched.write('matched_unimodal_catalog.fits', format='fits', overwrite=True)
print("Saved: matched_unimodal_catalog.fits")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the unimodal results
# ----> 2 unimodal = Table.read('unimodalcheck_200M_phase.csv', format='csv')
#       4 # Load the two cluster catalogs
#       5 cat_6811 = QTable.read('rcat_ngc6811_v0.fits')
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/registry/core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/connect.py:19, in io_read(format, filename, **kwargs)
#      17     format = re.sub(r"^ascii\.", "", format)
#      18     kwargs["format"] = format
# ---> 19 return read(filename, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
#     [... skipping similar frames: deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper at line 603 (2 times)]
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/ui.py:428, in read(table, guess, **kwargs)
#     426 fast_reader_rdr = get_reader(**fast_kwargs)
#     427 try:
# --> 428     dat = fast_reader_rdr.read(table)
#     429     _read_trace.append(
#     430         {
#     431             "kwargs": copy.deepcopy(fast_kwargs),
#    (...)
#     434         }
#     435     )
#     436 except (
#     437     core.ParameterError,
#     438     cparser.CParserError,
#     439     UnicodeEncodeError,
#     440 ) as err:
#     441     # special testing value to avoid falling back on the slow reader
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/fastbasic.py:131, in FastBasic.read(self, table)
#     128 # Put fast_reader dict back into kwargs.
#     129 self.kwargs["fast_reader"] = fast_reader
# --> 131 self.engine = cparser.CParser(
#     132     table,
#     133     self.strip_whitespace_lines,
#     134     self.strip_whitespace_fields,
#     135     delimiter=self.delimiter,
#     136     header_start=self.header_start,
#     137     comment=self.comment,
#     138     quotechar=self.quotechar,
#     139     data_start=self.data_start,
#     140     fill_extra_cols=self.fill_extra_cols,
#     141     **self.kwargs,
#     142 )
#     143 conversion_info = self._read_header()
#     144 self.check_header()
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/cparser.pyx:242, in astropy.io.ascii.cparser.CParser.__cinit__()
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/cparser.pyx:282, in astropy.io.ascii.cparser.CParser.setup_tokenizer()
#
# File ~/anaconda3/lib/python3.12/site-packages/astropy/io/ascii/cparser.pyx:133, in astropy.io.ascii.cparser.FileString.__cinit__()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'unimodalcheck_200M_phase.csv'
